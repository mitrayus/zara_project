# %% [markdown]
# This is the starting point for the zara project. We start by importing numpy and pandas packages.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Next we move on to uploading the dataset. The original version is by Varisha and available on Kaggle as Zara Clothes US (2024).

# %%
zd = pd.read_csv("C:/Users/48679025/Downloads/zara_clothes.csv")
zd.head()
# Out:
#    Product ID Product Position Promotion Product Category Seasonal  \
# 0      185102            Aisle        No         Clothing       No
# 1      188771            Aisle        No         Clothing       No
# 2      180176          End-cap       Yes         Clothing      Yes
# 3      112917            Aisle       Yes         Clothing      Yes
# 4      192936          End-cap        No         Clothing      Yes
#
#    Sales Volume brand                                                url  \
# 0          2823  Zara  https://www.zara.com/us/en/basic-puffer-jacket...
# 1           654  Zara  https://www.zara.com/us/en/tuxedo-jacket-p0889...
# 2          2220  Zara  https://www.zara.com/us/en/slim-fit-suit-jacke...
# 3          1568  Zara  https://www.zara.com/us/en/stretch-suit-jacket...
# 4          2942  Zara  https://www.zara.com/us/en/double-faced-jacket...
#
#                 sku                  name  \
# 0   272145190-250-2   BASIC PUFFER JACKET
# 1  324052738-800-46         TUXEDO JACKET
# 2  335342680-800-44  SLIM FIT SUIT JACKET
# 3  328303236-420-44   STRETCH SUIT JACKET
# 4   312368260-800-2   DOUBLE FACED JACKET
#
#                                          description   price currency  \
# 0  Puffer jacket made of tear-resistant ripstop f...   19.99      USD
# 1  Straight fit blazer. Pointed lapel collar and ...  169.00      USD
# 2  Slim fit jacket. Notched lapel collar. Long sl...  129.00      USD
# 3  Slim fit jacket made of viscose blend fabric. ...  129.00      USD
# 4  Jacket made of faux leather faux shearling wit...  139.00      USD
#
#                    scraped_at    terms section
# 0  2024-02-19T08:50:05.654618  jackets     MAN
# 1  2024-02-19T08:50:06.590930  jackets     MAN
# 2  2024-02-19T08:50:07.301419  jackets     MAN
# 3  2024-02-19T08:50:07.882922  jackets     MAN
# 4  2024-02-19T08:50:08.453847  jackets     MAN

# %% [markdown]
# Let's start by taking a quick look into the distribution of Product Position. As we can see, Aisle dominates the other two positions. We move on to check how much sales get affected when position changes from Aisle.

# %%
zd['Product Position'].value_counts()
# Out:
# Aisle             97
# End-cap           86
# Front of Store    69
# Name: Product Position, dtype: int64

# %% [markdown]
# Let's create binary variables. is_promotion equals one if the product is a promotion product and zero otherwise. Same goes for is_seasonal. is_premium equals one if product position is either End-Cap or front of store.

# %%
zd['is_promotion'] = zd['Promotion'].map({'Yes': 1, 'No': 0})
zd['is_seasonal'] = zd['Seasonal'].map({'Yes': 1, 'No': 0})

# %%
zd['is_premium'] = zd['Product Position'].apply(lambda x: 1 if x in ['End-cap', 'Front of Store'] else 0)

# %%
summary = zd.groupby('Product Position')['Sales Volume'].mean().sort_values(ascending=False)
print("Average Sales by Position:")
print(summary)
# Out:
# Average Sales by Position:
# Product Position
# Front of Store    1873.144928
# Aisle             1828.824742
# End-cap           1778.255814
# Name: Sales Volume, dtype: float64

# %%
summary = zd.groupby('Product Position')['price'].mean().sort_values(ascending=False)
print("Average Price by Position:")
print(summary)
# Out:
# Average Price by Position:
# Product Position
# Front of Store    88.893478
# Aisle             88.785773
# End-cap           81.276395
# Name: price, dtype: float64

# %%
import statsmodels.formula.api as smf

# %%
zd.columns = [c.replace(' ', '_').lower() for c in zd.columns]

# %% [markdown]
# Let's begin the first step of the analysis by doing a log transformation on sales and price. Then we perform a baseline multivariate linear regression.

# %%
zd['log_sales'] = np.log(zd['sales_volume'])
zd['log_price'] = np.log(zd['price'])

# %%
#OLS with log price and sales

log_model_with_controls = smf.ols(
    'log_sales ~ C(product_position) + log_price + is_promotion + is_seasonal + C(terms)', 
    data=zd
).fit()
print(log_model_with_controls.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_sales   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                 -0.016
# Method:                 Least Squares   F-statistic:                    0.5635
# Date:                Thu, 19 Feb 2026   Prob (F-statistic):              0.826
# Time:                        11:10:40   Log-Likelihood:                -152.99
# No. Observations:                 252   AIC:                             326.0
# Df Residuals:                     242   BIC:                             361.3
# Df Model:                           9
# Covariance Type:            nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# Intercept                                 7.8130      0.241     32.460      0.000       7.339       8.287
# C(product_position)[T.End-cap]           -0.0183      0.068     -0.270      0.787      -0.152       0.115
# C(product_position)[T.Front of Store]     0.0020      0.072      0.028      0.978      -0.140       0.144
# C(terms)[T.jeans]                        -0.1346      0.167     -0.804      0.422      -0.464       0.195
# C(terms)[T.shoes]                        -0.0133      0.094     -0.142      0.887      -0.198       0.171
# C(terms)[T.sweaters]                     -0.0961      0.088     -1.088      0.277      -0.270       0.078
# C(terms)[T.t-shirts]                     -0.1530      0.093     -1.641      0.102      -0.337       0.031
# log_price                                -0.0821      0.051     -1.596      0.112      -0.183       0.019
# is_promotion                              0.0197      0.058      0.343      0.732      -0.094       0.133
# is_seasonal                              -0.0087      0.059     -0.149      0.882      -0.124       0.107
# ==============================================================================
# Omnibus:                       20.572   Durbin-Watson:                   2.033
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.808
# Skew:                          -0.709   Prob(JB):                     1.11e-05
# Kurtosis:                       2.601   Cond. No.                         40.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Although the coefficients on the previous model were weak, including an interaction term shows improvement. For promotion items, end-cap placement shows a boost in sales.

# %%
#interaction: on-promotion*position

model_interaction = smf.ols(
    'log_sales ~ is_promotion * C(product_position) + log_price + is_seasonal + C(terms)', 
    data=zd
).fit()
print(model_interaction.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_sales   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                    0.6935
# Date:                Thu, 19 Feb 2026   Prob (F-statistic):              0.744
# Time:                        11:23:49   Log-Likelihood:                -151.66
# No. Observations:                 252   AIC:                             327.3
# Df Residuals:                     240   BIC:                             369.7
# Df Model:                          11
# Covariance Type:            nonrobust
# ======================================================================================================================
#                                                          coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------
# Intercept                                              7.8432      0.242     32.405      0.000       7.366       8.320
# C(product_position)[T.End-cap]                        -0.0941      0.094     -1.001      0.318      -0.279       0.091
# C(product_position)[T.Front of Store]                  0.0329      0.098      0.335      0.738      -0.161       0.227
# C(terms)[T.jeans]                                     -0.1209      0.168     -0.722      0.471      -0.451       0.209
# C(terms)[T.shoes]                                     -0.0161      0.094     -0.172      0.864      -0.201       0.169
# C(terms)[T.sweaters]                                  -0.0984      0.088     -1.115      0.266      -0.272       0.075
# C(terms)[T.t-shirts]                                  -0.1578      0.093     -1.690      0.092      -0.342       0.026
# is_promotion                                          -0.0140      0.093     -0.151      0.880      -0.197       0.169
# is_promotion:C(product_position)[T.End-cap]            0.1551      0.135      1.151      0.251      -0.110       0.421
# is_promotion:C(product_position)[T.Front of Store]    -0.0690      0.144     -0.480      0.632      -0.352       0.214
# log_price                                             -0.0847      0.051     -1.646      0.101      -0.186       0.017
# is_seasonal                                           -0.0122      0.059     -0.208      0.835      -0.128       0.103
# ==============================================================================
# Omnibus:                       19.367   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.645
# Skew:                          -0.696   Prob(JB):                     1.99e-05
# Kurtosis:                       2.647   Cond. No.                         41.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# For seasonal items, both end-cap and front-of-store placement show a boost in sales.

# %%
#interaction: seasonal*position
model_interaction = smf.ols(
    'log_sales ~ is_seasonal * C(product_position) + log_price + is_promotion + C(terms)', 
    data=zd
).fit()
print(model_interaction.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_sales   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                 -0.018
# Method:                 Least Squares   F-statistic:                    0.5994
# Date:                Thu, 19 Feb 2026   Prob (F-statistic):              0.829
# Time:                        11:26:28   Log-Likelihood:                -152.19
# No. Observations:                 252   AIC:                             328.4
# Df Residuals:                     240   BIC:                             370.7
# Df Model:                          11
# Covariance Type:            nonrobust
# =====================================================================================================================
#                                                         coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------
# Intercept                                             7.8593      0.244     32.215      0.000       7.379       8.340
# C(product_position)[T.End-cap]                       -0.1018      0.097     -1.054      0.293      -0.292       0.088
# C(product_position)[T.Front of Store]                -0.0262      0.103     -0.253      0.800      -0.230       0.177
# C(terms)[T.jeans]                                    -0.1466      0.168     -0.874      0.383      -0.477       0.184
# C(terms)[T.shoes]                                    -0.0194      0.094     -0.206      0.837      -0.204       0.165
# C(terms)[T.sweaters]                                 -0.0987      0.089     -1.108      0.269      -0.274       0.077
# C(terms)[T.t-shirts]                                 -0.1510      0.093     -1.616      0.107      -0.335       0.033
# is_seasonal                                          -0.0796      0.094     -0.844      0.400      -0.265       0.106
# is_seasonal:C(product_position)[T.End-cap]            0.1651      0.135      1.221      0.223      -0.101       0.432
# is_seasonal:C(product_position)[T.Front of Store]     0.0515      0.144      0.357      0.721      -0.233       0.336
# log_price                                            -0.0834      0.052     -1.615      0.108      -0.185       0.018
# is_promotion                                          0.0158      0.058      0.273      0.785      -0.098       0.129
# ==============================================================================
# Omnibus:                       20.267   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.207
# Skew:                          -0.697   Prob(JB):                     1.51e-05
# Kurtosis:                       2.585   Cond. No.                         42.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# If we aggregate end-cap and fron-of-store into a 'premium' category, the results are similar.

# %%
#interaction:promotion*premium
log_model_with_controls = smf.ols(
    'log_sales ~ is_premium*is_promotion + log_price + is_seasonal + C(terms)', 
    data=zd
).fit()
print(log_model_with_controls.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_sales   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                 -0.015
# Method:                 Least Squares   F-statistic:                    0.5797
# Date:                Thu, 19 Feb 2026   Prob (F-statistic):              0.813
# Time:                        12:05:53   Log-Likelihood:                -152.92
# No. Observations:                 252   AIC:                             325.8
# Df Residuals:                     242   BIC:                             361.1
# Df Model:                           9
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   7.8280      0.242     32.387      0.000       7.352       8.304
# C(terms)[T.jeans]          -0.1336      0.167     -0.799      0.425      -0.463       0.196
# C(terms)[T.shoes]          -0.0107      0.094     -0.114      0.909      -0.195       0.174
# C(terms)[T.sweaters]       -0.0960      0.088     -1.089      0.277      -0.270       0.078
# C(terms)[T.t-shirts]       -0.1539      0.093     -1.660      0.098      -0.337       0.029
# is_premium                 -0.0356      0.082     -0.436      0.663      -0.196       0.125
# is_promotion               -0.0146      0.093     -0.158      0.875      -0.197       0.168
# is_premium:is_promotion     0.0552      0.118      0.468      0.640      -0.177       0.288
# log_price                  -0.0817      0.051     -1.588      0.113      -0.183       0.020
# is_seasonal                -0.0100      0.059     -0.170      0.865      -0.125       0.106
# ==============================================================================
# Omnibus:                       20.700   Durbin-Watson:                   2.032
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.749
# Skew:                          -0.706   Prob(JB):                     1.15e-05
# Kurtosis:                       2.582   Cond. No.                         41.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#interaction:seasonal*premium
log_model_with_controls = smf.ols(
    'log_sales ~ is_seasonal*is_premium + log_price + is_promotion + C(terms)', 
    data=zd
).fit()
print(log_model_with_controls.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_sales   R-squared:                       0.024
# Model:                            OLS   Adj. R-squared:                 -0.012
# Method:                 Least Squares   F-statistic:                    0.6622
# Date:                Tue, 03 Mar 2026   Prob (F-statistic):              0.743
# Time:                        11:38:34   Log-Likelihood:                -152.54
# No. Observations:                 252   AIC:                             325.1
# Df Residuals:                     242   BIC:                             360.4
# Df Model:                           9
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  7.8497      0.242     32.374      0.000       7.372       8.327
# C(terms)[T.jeans]         -0.1466      0.167     -0.877      0.381      -0.476       0.183
# C(terms)[T.shoes]         -0.0176      0.093     -0.188      0.851      -0.202       0.166
# C(terms)[T.sweaters]      -0.0926      0.088     -1.051      0.294      -0.266       0.081
# C(terms)[T.t-shirts]      -0.1526      0.093     -1.648      0.101      -0.335       0.030
# is_seasonal               -0.0804      0.094     -0.855      0.393      -0.266       0.105
# is_premium                -0.0689      0.085     -0.809      0.419      -0.237       0.099
# is_seasonal:is_premium     0.1150      0.118      0.973      0.332      -0.118       0.348
# log_price                 -0.0813      0.051     -1.583      0.115      -0.182       0.020
# is_promotion               0.0163      0.058      0.283      0.778      -0.097       0.130
# ==============================================================================
# Omnibus:                       20.391   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.677
# Skew:                          -0.709   Prob(JB):                     1.19e-05
# Kurtosis:                       2.611   Cond. No.                         41.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Compared to jackets, sweaters have a bigger growth if promotion discount is applied, while tshirts have a lower growth.

# %%
#elasticity for different products
model_marginal = smf.ols(
    'log_sales ~ is_promotion * C(terms) + log_price + is_seasonal', 
    data=zd
).fit()
print(model_marginal.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_sales   R-squared:                       0.033
# Model:                            OLS   Adj. R-squared:                 -0.011
# Method:                 Least Squares   F-statistic:                    0.7457
# Date:                Thu, 19 Feb 2026   Prob (F-statistic):              0.694
# Time:                        13:08:15   Log-Likelihood:                -151.37
# No. Observations:                 252   AIC:                             326.7
# Df Residuals:                     240   BIC:                             369.1
# Df Model:                          11
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             7.8163      0.239     32.678      0.000       7.345       8.288
# C(terms)[T.jeans]                    -0.1369      0.210     -0.651      0.516      -0.551       0.278
# C(terms)[T.shoes]                     0.0026      0.132      0.019      0.984      -0.257       0.262
# C(terms)[T.sweaters]                 -0.1945      0.113     -1.717      0.087      -0.418       0.029
# C(terms)[T.t-shirts]                 -0.0844      0.123     -0.684      0.495      -0.327       0.159
# is_promotion                          0.0076      0.077      0.099      0.921      -0.144       0.159
# is_promotion:C(terms)[T.jeans]       -0.0075      0.341     -0.022      0.982      -0.679       0.664
# is_promotion:C(terms)[T.shoes]       -0.0310      0.180     -0.173      0.863      -0.385       0.323
# is_promotion:C(terms)[T.sweaters]     0.2170      0.162      1.341      0.181      -0.102       0.536
# is_promotion:C(terms)[T.t-shirts]    -0.1508      0.178     -0.846      0.398      -0.502       0.200
# log_price                            -0.0828      0.052     -1.600      0.111      -0.185       0.019
# is_seasonal                          -0.0079      0.059     -0.135      0.893      -0.123       0.108
# ==============================================================================
# Omnibus:                       19.875   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.317
# Skew:                          -0.707   Prob(JB):                     1.43e-05
# Kurtosis:                       2.646   Cond. No.                         59.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
summary = zd.groupby('terms')['sales_volume'].mean().sort_values(ascending=False)
print("Average price by terms:")
print(summary)
# Out:
# Average price by terms:
# terms
# shoes       1867.935484
# jackets     1853.342857
# sweaters    1835.170732
# t-shirts    1676.156250
# jeans       1665.000000
# Name: sales_volume, dtype: float64

# %%
#elasticity for different products
model_marginal = smf.ols(
    'log_sales ~ is_seasonal * C(terms) + log_price + is_promotion', 
    data=zd
).fit()
print(model_marginal.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_sales   R-squared:                       0.037
# Model:                            OLS   Adj. R-squared:                 -0.007
# Method:                 Least Squares   F-statistic:                    0.8439
# Date:                Thu, 19 Feb 2026   Prob (F-statistic):              0.596
# Time:                        13:24:22   Log-Likelihood:                -150.82
# No. Observations:                 252   AIC:                             325.6
# Df Residuals:                     240   BIC:                             368.0
# Df Model:                          11
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                            7.7624      0.239     32.499      0.000       7.292       8.233
# C(terms)[T.jeans]                    0.0655      0.212      0.309      0.758      -0.352       0.483
# C(terms)[T.shoes]                    0.0744      0.117      0.636      0.526      -0.156       0.305
# C(terms)[T.sweaters]                -0.1642      0.145     -1.136      0.257      -0.449       0.120
# C(terms)[T.t-shirts]                -0.1198      0.120     -0.998      0.319      -0.356       0.117
# is_seasonal                          0.0313      0.076      0.410      0.682      -0.119       0.182
# is_seasonal:C(terms)[T.jeans]       -0.5199      0.340     -1.530      0.127      -1.189       0.149
# is_seasonal:C(terms)[T.shoes]       -0.2248      0.186     -1.210      0.227      -0.591       0.141
# is_seasonal:C(terms)[T.sweaters]     0.0875      0.173      0.506      0.613      -0.253       0.428
# is_seasonal:C(terms)[T.t-shirts]    -0.0693      0.180     -0.386      0.700      -0.423       0.285
# log_price                           -0.0773      0.051     -1.507      0.133      -0.178       0.024
# is_promotion                         0.0268      0.058      0.465      0.643      -0.087       0.140
# ==============================================================================
# Omnibus:                       20.541   Durbin-Watson:                   2.040
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.634
# Skew:                          -0.705   Prob(JB):                     1.22e-05
# Kurtosis:                       2.590   Cond. No.                         59.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
